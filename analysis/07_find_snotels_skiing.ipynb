# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from simplekml import Kml

# Load the KML file
kml_file_path = '/home/cdalden/summa_setup/analysis/Lift_Database_Washington.kml'
gdf = gpd.read_file(kml_file_path, driver='KML')

# Plot the data
gdf.plot()
plt.show()
